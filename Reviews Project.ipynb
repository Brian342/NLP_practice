# %% [markdown]
# # Reviews Company

# %%
# !conda install -c conda-forge sentence-transformers
# !pip install scikit-learn
# !pip install numpy pandas
# !pip show sentence-transformers
# !pip install spacy

# %%
# import required packages
import pandas as pd
import numpy as np
import spacy
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, normalize
from spacy.matcher import PhraseMatcher
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2025-11-18 10:44:55.421389: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pd.set_option("display.max_colwidth",None)
# pd.reset_option("display.max_row",None)

# %%
data = pd.read_csv("Data_Merge_Reviews.csv")
data
# Out:
#                      Job Title  Job Rating        Time  \
# 0             Brand Ambassador         5.0  2025-08-08
# 1      Senior Mobile Developer         4.0  2025-07-28
# 2              Project Manager         4.0  2025-07-15
# 3               Ict Technician         5.0  2025-07-18
# 4                       Intern         5.0  2025-07-15
# ...                        ...         ...         ...
# 25037         Planning officer         4.0  2022-03-31
# 25038  Senior business analyst         4.0  2022-05-14
# 25039   Senior program manager         3.0  2016-05-02
# 25040    Ban assurance officer         1.0  2022-10-17
# 25041   Channel administrative         1.0  2013-10-09
#
#                                  Job Status  \
# 0         Former employee, more than 1 year
# 1      Current contractor, more than 1 year
# 2        Former employee, more than 3 years
# 3                           Former employee
# 4           Former intern, less than 1 year
# ...                                     ...
# 25037                       Former employee
# 25038                      Current employee
# 25039                       Former employee
# 25040     Former employee, more than 1 year
# 25041    Former employee, more than 5 years
#
#                                                                                                                                                                   Pros  \
# 0                                                                         Flexible Hours, Supportive Team, Good Training, Fun Work Environment, Opportunity To Travel.
# 1                                                                                                  Great For Gaining Experience On Large Scale Enterprise Applications
# 2      Strong Support For Professional Growth Through Training Exposure To LargeScale, Impactful Projects Across Kenya Competitive Salary And PerformanceBased Bonuses
# 3                                                                                                                                      The Working Experience Was Good
# 4                                                                                                                             Great Work Environment. Regular Bonuses.
# ...                                                                                                                                                                ...
# 25037                                                                                                                           have good medical covers for employees
# 25038                                                                                                                            Has good Learning potential for staff
# 25039                                                                                                                                Potential for great social impact
# 25040                                                                                                            Medical insurance cover. Low interest loans for staff
# 25041                                                                                                                exposure and experience good. growth too possible
#
#                                                                                                                                          Cons  \
# 0      Inconsistent Hours, Limited Career Growth, Commission Structure Can Be Unclear, Standing For Long Hours, Sometimes Slow Communication.
# 1                                                                                                                A Lot Of Shifting Priorities
# 2                                                Occasional Tight Deadlines And HighPressure Timelines Bureaucracy Can Delay Project SignOffs
# 3                                                                                               There Are No Major Drawbacks I Can Talk About
# 4                                                                                                                         None I Can Think Of
# ...                                                                                                                                       ...
# 25037                                                                                                        terms of employment are contract
# 25038                                                                                                        Working schedule is not flexible
# 25039                                                                                                                    Can be slow at times
# 25040                                Bad management Less than appropriate pay Extremely long work hours Extensive workload Toxic work culture
# 25041                                                                   work environment not good, need to improve a lot on HR related issues
#
#       Company_Name
# 0        Safaricom
# 1        Safaricom
# 2        Safaricom
# 3        Safaricom
# 4        Safaricom
# ...            ...
# 25037       Equity
# 25038       Equity
# 25039       Equity
# 25040       Equity
# 25041       Equity
#
# [25042 rows x 7 columns]

# %%
# using 
data2 = data

# %%
def split_info(df: pd.Series)-> pd.DataFrame:
    employment_type = []
    role_type = []
    duration = []
    for raw in df:
        data = raw.split()
        emp = rol = dur = "default"

        if len(data) >=2:
            emp = data[0]
            rol = data[1].replace(",", "")

        if "less than 1 year" in raw:
            dur = "<1 year"
        elif "more than 1 year" in raw:
            dur = "1 - 3 year"
        elif "more than 3 years" in raw:
            dur = ">3 year"
        employment_type.append(emp)
        role_type.append(rol)
        duration.append(dur)
         
    return pd.DataFrame({
       "Employment_Type":employment_type,
        "Role_Type":role_type,
        "Duration":duration
    })
new_cols = split_info(data2["Job Status"])

# %%
data2 = pd.concat([data2, new_cols], axis=1)
data2 = data2[
    ["Job Title", "Job Rating", "Time", "Job Status", 
     "Employment_Type", "Role_Type", "Duration",
     "Pros", "Cons", "Company_Name"]
]

# %%
# data2.drop(["Employment_Type", "Role_Type", "Duration"], axis=1, inplace=True)

# %%
data2
# Out:
#                      Job Title  Job Rating        Time  \
# 0             Brand Ambassador         5.0  2025-08-08
# 1      Senior Mobile Developer         4.0  2025-07-28
# 2              Project Manager         4.0  2025-07-15
# 3               Ict Technician         5.0  2025-07-18
# 4                       Intern         5.0  2025-07-15
# ...                        ...         ...         ...
# 25037         Planning officer         4.0  2022-03-31
# 25038  Senior business analyst         4.0  2022-05-14
# 25039   Senior program manager         3.0  2016-05-02
# 25040    Ban assurance officer         1.0  2022-10-17
# 25041   Channel administrative         1.0  2013-10-09
#
#                                  Job Status Employment_Type   Role_Type  \
# 0         Former employee, more than 1 year          Former    employee
# 1      Current contractor, more than 1 year         Current  contractor
# 2        Former employee, more than 3 years          Former    employee
# 3                           Former employee          Former    employee
# 4           Former intern, less than 1 year          Former      intern
# ...                                     ...             ...         ...
# 25037                       Former employee          Former    employee
# 25038                      Current employee         Current    employee
# 25039                       Former employee          Former    employee
# 25040     Former employee, more than 1 year          Former    employee
# 25041    Former employee, more than 5 years          Former    employee
#
#          Duration  \
# 0      1 - 3 year
# 1      1 - 3 year
# 2         >3 year
# 3         default
# 4         <1 year
# ...           ...
# 25037     default
# 25038     default
# 25039     default
# 25040  1 - 3 year
# 25041     default
#
#                                                                                                                                                                   Pros  \
# 0                                                                         Flexible Hours, Supportive Team, Good Training, Fun Work Environment, Opportunity To Travel.
# 1                                                                                                  Great For Gaining Experience On Large Scale Enterprise Applications
# 2      Strong Support For Professional Growth Through Training Exposure To LargeScale, Impactful Projects Across Kenya Competitive Salary And PerformanceBased Bonuses
# 3                                                                                                                                      The Working Experience Was Good
# 4                                                                                                                             Great Work Environment. Regular Bonuses.
# ...                                                                                                                                                                ...
# 25037                                                                                                                           have good medical covers for employees
# 25038                                                                                                                            Has good Learning potential for staff
# 25039                                                                                                                                Potential for great social impact
# 25040                                                                                                            Medical insurance cover. Low interest loans for staff
# 25041                                                                                                                exposure and experience good. growth too possible
#
#                                                                                                                                          Cons  \
# 0      Inconsistent Hours, Limited Career Growth, Commission Structure Can Be Unclear, Standing For Long Hours, Sometimes Slow Communication.
# 1                                                                                                                A Lot Of Shifting Priorities
# 2                                                Occasional Tight Deadlines And HighPressure Timelines Bureaucracy Can Delay Project SignOffs
# 3                                                                                               There Are No Major Drawbacks I Can Talk About
# 4                                                                                                                         None I Can Think Of
# ...                                                                                                                                       ...
# 25037                                                                                                        terms of employment are contract
# 25038                                                                                                        Working schedule is not flexible
# 25039                                                                                                                    Can be slow at times
# 25040                                Bad management Less than appropriate pay Extremely long work hours Extensive workload Toxic work culture
# 25041                                                                   work environment not good, need to improve a lot on HR related issues
#
#       Company_Name
# 0        Safaricom
# 1        Safaricom
# 2        Safaricom
# 3        Safaricom
# 4        Safaricom
# ...            ...
# 25037       Equity
# 25038       Equity
# 25039       Equity
# 25040       Equity
# 25041       Equity
#
# [25042 rows x 10 columns]

# %%
data2["Employment_Type"].unique().tolist()
# Out:
# ['Former', 'Current', 'KEY']

# %%
data2[data2["Employment_Type"] == "KEY"]
# Out:
#              Job Title  Job Rating        Time  \
# 467  Online Data Entry         5.0  2021-07-21
#
#                                   Job Status Employment_Type Role_Type  \
# 467  KEY NOT FOUND: jobLine.seasonal-current             KEY       NOT
#
#     Duration                               Pros  \
# 467  default  The Company Pays Well And On Time
#
#                                           Cons Company_Name
# 467  Commissions Were Very Few Also Allowances    Safaricom

# %%
data2.drop(467, axis=0, inplace=True)

# %%
data2.set_index("Job Title", inplace=True)

# %%
data2= data2.reset_index()

# %%
data2["Role_Type"].unique().tolist()
# Out:
# ['employee', 'contractor', 'intern', 'temporary', 'freelancer']

# %%
# jobrole = {"intern":"Internship"}

# %%
data2["Role_Type"].replace("intern", "internship",inplace=True)

# %%
# Normalize text (lowercase, remove weird symbols, etc.).
data2["Pros"] = data2["Pros"].str.lower()

# %%
data2["Job Title"] = data2["Job Title"].str.lower()

# %%
# This command is used to change the it's to it is 
import contractions
data2["Cons"] = data2["Cons"].apply(lambda x: contractions.fix(x) if isinstance(x, str) else x)

# %%
data2[["Cons","Company_Name"]].head(50)
# Out:
#                                                                                                                                       Cons  \
# 0   Inconsistent Hours, Limited Career Growth, Commission Structure Can Be Unclear, Standing For Long Hours, Sometimes Slow Communication.
# 1                                                                                                             A Lot Of Shifting Priorities
# 2                                             Occasional Tight Deadlines And HighPressure Timelines Bureaucracy Can Delay Project SignOffs
# 3                                                                                            There Are No Major Drawbacks I Can Talk About
# 4                                                                                                                      None I Can Think Of
# 5                                                                                                        Workload May Be Too Much Sometime
# 6                                                                              Tough Management  Extreme Work Conditions Pressure Nepotism
# 7                                                                                                      Is Place That Offers Carrier Growth
# 8                                                                                 No Growth Compensation For Customer Care Is Not Worth It
# 9                                                                                                            Have To Meet Strict Deadlines
# 10                                                                                                   Working Via Agency No Room For Growth
# 11                                                                                                    Corporate Work Pressure And Politics
# 12                                                     Limited Advancement Opportunities And Outdated Technology Systems Need Improvement.
# 13                                   HighPressure, Competitive, And Sometimes Bureaucratic Environment, Which Can Impact WorkLife Balance.
# 14                                                                    No Work Life Balance. Scalling Is Almost Impossible As A Contractor.
# 15                                                                                                None That I Noticed. Good Working Place.
# 16                                                                                                           None I Can Think Of Right Now
# 17                                                                                                  Can Do Better With Salary And Benefits
# 18                       Too Much Focus On Short Term Goals  Work Overload, Easy To Find Only One Engineer Working On A Huge Project Alone
# 19                                                                                    Too Much Pressure Plus There Is No Work Life Balance
# 20                                                                                                                Not So Much Cons To Give
# 21                                                                                                                 The Pay Could Be Better
# 22                                                                     The Pay Is Less Comission Compared To Similar Roles In The Industry
# 23                                                             Minimal Career Growth Career Progression In Some Areas Is Almost Impossible
# 24                                                                                                      I Have No Cons From My Experience.
# 25                                                                                                                Late Pay Every Month Too
# 26                                                                Lack Of Innovating & Experimenting Culture Limited To Subpar Initiative.
# 27                                                                       The Underpay Their Technology Employees Compared To The Industry.
# 28                                                                                                   Very Difficult To Get The Opportunity
# 29                                                                                          Longer Commuteless Opportunity For Advancement
# 30                                                                                            Nepotism In Recruitment, Complex Interviews.
# 31                                                                                            Nothing Negative To Review The Company About
# 32                                                                                                Not Much It Does Not Get Better They Saf
# 33                                                                                           Failure To Renew Contract Dispite Performance
# 34                                                                                                  Long Hours And Harsh Work Environment.
# 35                                                                                            Have A Positive Attitude To Learn New Skills
# 36   Scope Of Projects: While Projects Were Insightful, Expanding Intern Roles On Larger Initiatives Could Further Enhance The Experience.
# 37                                                                                             Bureaucracy Creeping In To The Organization
# 38                                                                                                Employee Growth Internally Is Very Slow.
# 39                                                                                            No Cons At The Moment. Enjoyed Working There
# 40                                                                                              Fast Paced Enviroment . Very Large Company
# 41                                                                                                       They Have No Cons During My Stay.
# 42                                                                                                           There Are No Cons As For Now.
# 43         Potential For Long Hours, Pressure, And A Perceived Lack Of WorkLife Balance, Along With Concerns About Salary Competitiveness.
# 44                                                                                                  Ai Threatens The Permanency Of The Job
# 45                                                                               Terrible Company Culture, Individuaistic And No Integrity
# 46                                                                                                               None At The Moment On Saf
# 47                                                                               Salary Scales Are PreDetermined Unless You Are Headhunted
# 48                                                                                                    None A=Execept Being Asupser Swamped
# 49                                                                                          In Developing Financial Records And Statements
#
#    Company_Name
# 0     Safaricom
# 1     Safaricom
# 2     Safaricom
# 3     Safaricom
# 4     Safaricom
# 5     Safaricom
# 6     Safaricom
# 7     Safaricom
# 8     Safaricom
# 9     Safaricom
# 10    Safaricom
# 11    Safaricom
# 12    Safaricom
# 13    Safaricom
# 14    Safaricom
# 15    Safaricom
# 16    Safaricom
# 17    Safaricom
# 18    Safaricom
# 19    Safaricom
# 20    Safaricom
# 21    Safaricom
# 22    Safaricom
# 23    Safaricom
# 24    Safaricom
# 25    Safaricom
# 26    Safaricom
# 27    Safaricom
# 28    Safaricom
# 29    Safaricom
# 30    Safaricom
# 31    Safaricom
# 32    Safaricom
# 33    Safaricom
# 34    Safaricom
# 35    Safaricom
# 36    Safaricom
# 37    Safaricom
# 38    Safaricom
# 39    Safaricom
# 40    Safaricom
# 41    Safaricom
# 42    Safaricom
# 43    Safaricom
# 44    Safaricom
# 45    Safaricom
# 46    Safaricom
# 47    Safaricom
# 48    Safaricom
# 49    Safaricom

# %%
from spellchecker import SpellChecker
spell = SpellChecker()

def correct_sentence(text):
    if not isinstance(text, str):
        text = ""
    words = text.split()
    correct_words = []

    for word in words:
        if word.lower() in spell:
            correct_words.append(word)
        else:
            correction = spell.correction(word)
            correct_words.append(correction if correction else word)
            
    return " ".join(correct_words)

# %%
# data2["Corrected_Cons"] = data2["Cons"].fillna("").apply(correct_sentence)
data2
# Out:
#                      Job Title  Job Rating        Time  \
# 0             brand ambassador         5.0  2025-08-08
# 1      senior mobile developer         4.0  2025-07-28
# 2              project manager         4.0  2025-07-15
# 3               ict technician         5.0  2025-07-18
# 4                       intern         5.0  2025-07-15
# ...                        ...         ...         ...
# 25036         planning officer         4.0  2022-03-31
# 25037  senior business analyst         4.0  2022-05-14
# 25038   senior program manager         3.0  2016-05-02
# 25039    ban assurance officer         1.0  2022-10-17
# 25040   channel administrative         1.0  2013-10-09
#
#                                  Job Status Employment_Type   Role_Type  \
# 0         Former employee, more than 1 year          Former    employee
# 1      Current contractor, more than 1 year         Current  contractor
# 2        Former employee, more than 3 years          Former    employee
# 3                           Former employee          Former    employee
# 4           Former intern, less than 1 year          Former  internship
# ...                                     ...             ...         ...
# 25036                       Former employee          Former    employee
# 25037                      Current employee         Current    employee
# 25038                       Former employee          Former    employee
# 25039     Former employee, more than 1 year          Former    employee
# 25040    Former employee, more than 5 years          Former    employee
#
#          Duration  \
# 0      1 - 3 year
# 1      1 - 3 year
# 2         >3 year
# 3         default
# 4         <1 year
# ...           ...
# 25036     default
# 25037     default
# 25038     default
# 25039  1 - 3 year
# 25040     default
#
#                                                                                                                                                                   Pros  \
# 0                                                                         flexible hours, supportive team, good training, fun work environment, opportunity to travel.
# 1                                                                                                  great for gaining experience on large scale enterprise applications
# 2      strong support for professional growth through training exposure to largescale, impactful projects across kenya competitive salary and performancebased bonuses
# 3                                                                                                                                      the working experience was good
# 4                                                                                                                             great work environment. regular bonuses.
# ...                                                                                                                                                                ...
# 25036                                                                                                                           have good medical covers for employees
# 25037                                                                                                                            has good learning potential for staff
# 25038                                                                                                                                potential for great social impact
# 25039                                                                                                            medical insurance cover. low interest loans for staff
# 25040                                                                                                                exposure and experience good. growth too possible
#
#                                                                                                                                          Cons  \
# 0      Inconsistent Hours, Limited Career Growth, Commission Structure Can Be Unclear, Standing For Long Hours, Sometimes Slow Communication.
# 1                                                                                                                A Lot Of Shifting Priorities
# 2                                                Occasional Tight Deadlines And HighPressure Timelines Bureaucracy Can Delay Project SignOffs
# 3                                                                                               There Are No Major Drawbacks I Can Talk About
# 4                                                                                                                         None I Can Think Of
# ...                                                                                                                                       ...
# 25036                                                                                                        terms of employment are contract
# 25037                                                                                                        Working schedule is not flexible
# 25038                                                                                                                    Can be slow at times
# 25039                                Bad management Less than appropriate pay Extremely long work hours Extensive workload Toxic work culture
# 25040                                                                   work environment not good, need to improve a lot on HR related issues
#
#       Company_Name
# 0        Safaricom
# 1        Safaricom
# 2        Safaricom
# 3        Safaricom
# 4        Safaricom
# ...            ...
# 25036       Equity
# 25037       Equity
# 25038       Equity
# 25039       Equity
# 25040       Equity
#
# [25041 rows x 10 columns]

# %%
# load spacy
nlp = spacy.load("en_core_web_lg")

# patterns = [
#            "ict technician", "ict officer", "ict manager", "ict consultant", "ict manager", "ict project manager",
#            "ict security analyst", "ict service desk analyst", "ict - software engineer", "ict applications support"]

# adding entity rule
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
unique_titles = data2["Job Title"].dropna().unique().tolist()
pattern_doc = [nlp.make_doc(title.lower()) for title in unique_titles]
matcher.add("JOB_ROLE", pattern_doc)

status_map = {
    "ft": "Full-time",
    "full-time": "Full-time",
    "full time": "Full-time",
    "intern": "Internship",
    "internship": "Internship",
    "intern (paid)": "Internship",
    "contract": "Contract",
    "contractor": "Contract"
}
mapping = {"one": 1.0, "two": 2.0,"three": 3.0, "four": 4.0,"five":5.0}

def clean_status(status):
    if pd.isna(status): return None
    if "intern" in status: return "Internship"
    if "contract" in status: return "Contract"
    if "full" in status: return "Full-time"
    status = status.lower().strip()
    return status_map.get(status, status.title())

# normalize the job rating
def clean_rating(rating):
    if pd.isna(rating): return None
    if isinstance(rating, str):
        rating = rating.lower().strip()
        if rating in rating_map:
            return rating_map(rating)
        match = re.search(r"[0-9.]+", rating)
        return float(match.group()) if match else None
    return float(rating)

# text cleaning with spacy
def spacy_clean(text):
    if not isinstance(text,str) or not text.strip():
        return "", []
    doc = nlp(text.lower())
    tokens = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    matches = matcher(doc)
    job_roles = [doc[start:end].text for _, start, end in matches]
    return " ".join(tokens), {"NER": entities, "ROLES": job_roles}
        
def process_row(row):
    job_title_clean, job_title_entities = spacy_clean(row.get("Job Title", ""))
    pros_clean, pros_entities = spacy_clean(row.get("Pros", ""))
    cons_clean, cons_entities = spacy_clean(row.get("Cons", ""))

    return pd.Series({
        "Job Title Clean": job_title_clean,
        "Job Title Entities": job_title_entities,
        "Pros Clean": pros_clean,
        "Pros Entities": pros_entities,
        "Cons Clean": cons_clean,
        "Cons Entities": cons_entities,
        "Cleaned Status": clean_status(row.get("Job Status", "")),
        "Cleaned Rating": clean_rating(row.get("Job Rating", ""))
    })

data2_cleaned = data2.apply(process_row, axis=1)
print(data2_cleaned.head())
# Out:
#            Job Title Clean  \
# 0         brand ambassador
# 1  senior mobile developer
# 2          project manager
# 3           ict technician
# 4                   intern
#
#                                                                    Job Title Entities  \
# 0                   {'NER': [], 'ROLES': ['brand', 'brand ambassador', 'ambassador']}
# 1  {'NER': [], 'ROLES': ['senior mobile developer', 'mobile developer', 'developer']}
# 2                     {'NER': [], 'ROLES': ['project', 'project manager', 'manager']}
# 3         {'NER': [('ict', 'ORG')], 'ROLES': ['ict', 'ict technician', 'technician']}
# 4                                                    {'NER': [], 'ROLES': ['intern']}
#
#                                                                                                                           Pros Clean  \
# 0                                                flexible hour supportive team good training fun work environment opportunity travel
# 1                                                                           great gain experience large scale enterprise application
# 2  strong support professional growth training exposure largescale impactful project kenya competitive salary performancebased bonus
# 3                                                                                                            working experience good
# 4                                                                                               great work environment regular bonus
#
#                                                                                Pros Entities  \
# 0                                                 {'NER': [], 'ROLES': ['good', 'training']}
# 1                                                            {'NER': [], 'ROLES': ['great']}
# 2  {'NER': [('kenya', 'GPE')], 'ROLES': ['support', 'professional', 'training', 'projects']}
# 3                                                             {'NER': [], 'ROLES': ['good']}
# 4                                                            {'NER': [], 'ROLES': ['great']}
#
#                                                                                                 Cons Clean  \
# 0  inconsistent hour limited career growth commission structure unclear stand long hour slow communication
# 1                                                                                       lot shift priority
# 2                        occasional tight deadline highpressure timeline bureaucracy delay project signoff
# 3                                                                                      major drawback talk
# 4                                                                                                    think
#
#                                                        Cons Entities  \
# 0  {'NER': [('hours', 'TIME'), ('long hours', 'TIME')], 'ROLES': []}
# 1                                           {'NER': [], 'ROLES': []}
# 2                                  {'NER': [], 'ROLES': ['project']}
# 3                                           {'NER': [], 'ROLES': []}
# 4                                           {'NER': [], 'ROLES': []}
#
#                        Cleaned Status  Cleaned Rating
# 0   Former Employee, More Than 1 Year             5.0
# 1                            Contract             4.0
# 2  Former Employee, More Than 3 Years             4.0
# 3                     Former Employee             5.0
# 4                          Internship             5.0

# %%
nlp("data scientist").similarity(nlp("machine learning engineer"))
# Out:
# 0.5121792330607114

# %%
nlp("internship").similarity(nlp("full-time"))
# Out:
# 0.22726951282021637

# %%
nlp("project manager").similarity(nlp("team lead"))
# Out:
# 0.5455771796658736

# %%
data2.columns
# Out:
# Index(['Job Title', 'Job Rating', 'Time', 'Job Status', 'Employment_Type',
#        'Role_Type', 'Duration', 'Pros', 'Cons', 'Company_Name'],
#       dtype='object')

# %%
# apply the cleaning
# data2_cleaned["Employment_Type"] = data2_cleaned["Employment_Type"].apply(clean_status)

# %%
# data2_cleaned["Cleaned Rating"] = data2_cleaned["Cleaned Rating"].apply(clean_rating)

# %%
# data2_cleaned["Company_Name"] = data2_cleaned["Company_Name"].str.lower().str.replace('r[^a-zA-Z]','', regex=True).str.strip()

# %%
# data2_cleaned[["Job Title Entities", "Job Title"]].head(50)

# %%
data2_cleaned
# Out:
#                Job Title Clean  \
# 0             brand ambassador
# 1      senior mobile developer
# 2              project manager
# 3               ict technician
# 4                       intern
# ...                        ...
# 25036         planning officer
# 25037  senior business analyst
# 25038   senior program manager
# 25039    ban assurance officer
# 25040   channel administrative
#
#                                                                                                 Job Title Entities  \
# 0                                                {'NER': [], 'ROLES': ['brand', 'brand ambassador', 'ambassador']}
# 1                               {'NER': [], 'ROLES': ['senior mobile developer', 'mobile developer', 'developer']}
# 2                                                  {'NER': [], 'ROLES': ['project', 'project manager', 'manager']}
# 3                                      {'NER': [('ict', 'ORG')], 'ROLES': ['ict', 'ict technician', 'technician']}
# 4                                                                                 {'NER': [], 'ROLES': ['intern']}
# ...                                                                                                            ...
# 25036                                                        {'NER': [], 'ROLES': ['planning officer', 'officer']}
# 25037                             {'NER': [], 'ROLES': ['senior business analyst', 'business analyst', 'analyst']}
# 25038  {'NER': [], 'ROLES': ['senior program', 'senior program manager', 'program', 'program manager', 'manager']}
# 25039                                      {'NER': [], 'ROLES': ['ban assurance officer', 'assurance', 'officer']}
# 25040          {'NER': [('channel administrative', 'ORG')], 'ROLES': ['channel administrative', 'administrative']}
#
#                                                                                                                               Pros Clean  \
# 0                                                    flexible hour supportive team good training fun work environment opportunity travel
# 1                                                                               great gain experience large scale enterprise application
# 2      strong support professional growth training exposure largescale impactful project kenya competitive salary performancebased bonus
# 3                                                                                                                working experience good
# 4                                                                                                   great work environment regular bonus
# ...                                                                                                                                  ...
# 25036                                                                                                        good medical cover employee
# 25037                                                                                                      good learning potential staff
# 25038                                                                                                      potential great social impact
# 25039                                                                                    medical insurance cover low interest loan staff
# 25040                                                                                           exposure experience good growth possible
#
#                                                                                    Pros Entities  \
# 0                                                     {'NER': [], 'ROLES': ['good', 'training']}
# 1                                                                {'NER': [], 'ROLES': ['great']}
# 2      {'NER': [('kenya', 'GPE')], 'ROLES': ['support', 'professional', 'training', 'projects']}
# 3                                                                 {'NER': [], 'ROLES': ['good']}
# 4                                                                {'NER': [], 'ROLES': ['great']}
# ...                                                                                          ...
# 25036                                                             {'NER': [], 'ROLES': ['good']}
# 25037                                                             {'NER': [], 'ROLES': ['good']}
# 25038                                                            {'NER': [], 'ROLES': ['great']}
# 25039                                                                   {'NER': [], 'ROLES': []}
# 25040                                                             {'NER': [], 'ROLES': ['good']}
#
#                                                                                                     Cons Clean  \
# 0      inconsistent hour limited career growth commission structure unclear stand long hour slow communication
# 1                                                                                           lot shift priority
# 2                            occasional tight deadline highpressure timeline bureaucracy delay project signoff
# 3                                                                                          major drawback talk
# 4                                                                                                        think
# ...                                                                                                        ...
# 25036                                                                                 term employment contract
# 25037                                                                                   work schedule flexible
# 25038                                                                                                slow time
# 25039            bad management appropriate pay extremely long work hour extensive workload toxic work culture
# 25040                                                   work environment good need improve lot hr relate issue
#
#                                                            Cons Entities  \
# 0      {'NER': [('hours', 'TIME'), ('long hours', 'TIME')], 'ROLES': []}
# 1                                               {'NER': [], 'ROLES': []}
# 2                                      {'NER': [], 'ROLES': ['project']}
# 3                                               {'NER': [], 'ROLES': []}
# 4                                               {'NER': [], 'ROLES': []}
# ...                                                                  ...
# 25036                                           {'NER': [], 'ROLES': []}
# 25037                                           {'NER': [], 'ROLES': []}
# 25038                                           {'NER': [], 'ROLES': []}
# 25039              {'NER': [('hours', 'TIME')], 'ROLES': ['management']}
# 25040                               {'NER': [], 'ROLES': ['good', 'hr']}
#
#                            Cleaned Status  Cleaned Rating
# 0       Former Employee, More Than 1 Year             5.0
# 1                                Contract             4.0
# 2      Former Employee, More Than 3 Years             4.0
# 3                         Former Employee             5.0
# 4                              Internship             5.0
# ...                                   ...             ...
# 25036                     Former Employee             4.0
# 25037                    Current Employee             4.0
# 25038                     Former Employee             3.0
# 25039   Former Employee, More Than 1 Year             1.0
# 25040  Former Employee, More Than 5 Years             1.0
#
# [25041 rows x 8 columns]

# %% [markdown]
# # Transformers implementation

# %%
data2_cleaned["Time"] = data2["Time"]
data2_cleaned["Employment_Type"] = data2["Employment_Type"]
data2_cleaned["Role_Type"] = data2["Role_Type"]
data2_cleaned["Duration"] = data2["Duration"]
data2_cleaned["Company_Name"] = data2["Company_Name"]

# %%
data2_cleaned['combined_text'] = (
    data2_cleaned['Job Title Clean'].fillna('') + ' ' +
    data2_cleaned['Pros Clean'].fillna('') + ' ' +
    data2_cleaned['Cons Clean'].fillna('') + ' ' +
    data2_cleaned['Role_Type'].fillna('')
)

# %%
data2_cleaned
# Out:
#                Job Title Clean  \
# 0             brand ambassador
# 1      senior mobile developer
# 2              project manager
# 3               ict technician
# 4                       intern
# ...                        ...
# 25036         planning officer
# 25037  senior business analyst
# 25038   senior program manager
# 25039    ban assurance officer
# 25040   channel administrative
#
#                                                                                                 Job Title Entities  \
# 0                                                {'NER': [], 'ROLES': ['brand', 'brand ambassador', 'ambassador']}
# 1                               {'NER': [], 'ROLES': ['senior mobile developer', 'mobile developer', 'developer']}
# 2                                                  {'NER': [], 'ROLES': ['project', 'project manager', 'manager']}
# 3                                      {'NER': [('ict', 'ORG')], 'ROLES': ['ict', 'ict technician', 'technician']}
# 4                                                                                 {'NER': [], 'ROLES': ['intern']}
# ...                                                                                                            ...
# 25036                                                        {'NER': [], 'ROLES': ['planning officer', 'officer']}
# 25037                             {'NER': [], 'ROLES': ['senior business analyst', 'business analyst', 'analyst']}
# 25038  {'NER': [], 'ROLES': ['senior program', 'senior program manager', 'program', 'program manager', 'manager']}
# 25039                                      {'NER': [], 'ROLES': ['ban assurance officer', 'assurance', 'officer']}
# 25040          {'NER': [('channel administrative', 'ORG')], 'ROLES': ['channel administrative', 'administrative']}
#
#                                                                                                                               Pros Clean  \
# 0                                                    flexible hour supportive team good training fun work environment opportunity travel
# 1                                                                               great gain experience large scale enterprise application
# 2      strong support professional growth training exposure largescale impactful project kenya competitive salary performancebased bonus
# 3                                                                                                                working experience good
# 4                                                                                                   great work environment regular bonus
# ...                                                                                                                                  ...
# 25036                                                                                                        good medical cover employee
# 25037                                                                                                      good learning potential staff
# 25038                                                                                                      potential great social impact
# 25039                                                                                    medical insurance cover low interest loan staff
# 25040                                                                                           exposure experience good growth possible
#
#                                                                                    Pros Entities  \
# 0                                                     {'NER': [], 'ROLES': ['good', 'training']}
# 1                                                                {'NER': [], 'ROLES': ['great']}
# 2      {'NER': [('kenya', 'GPE')], 'ROLES': ['support', 'professional', 'training', 'projects']}
# 3                                                                 {'NER': [], 'ROLES': ['good']}
# 4                                                                {'NER': [], 'ROLES': ['great']}
# ...                                                                                          ...
# 25036                                                             {'NER': [], 'ROLES': ['good']}
# 25037                                                             {'NER': [], 'ROLES': ['good']}
# 25038                                                            {'NER': [], 'ROLES': ['great']}
# 25039                                                                   {'NER': [], 'ROLES': []}
# 25040                                                             {'NER': [], 'ROLES': ['good']}
#
#                                                                                                     Cons Clean  \
# 0      inconsistent hour limited career growth commission structure unclear stand long hour slow communication
# 1                                                                                           lot shift priority
# 2                            occasional tight deadline highpressure timeline bureaucracy delay project signoff
# 3                                                                                          major drawback talk
# 4                                                                                                        think
# ...                                                                                                        ...
# 25036                                                                                 term employment contract
# 25037                                                                                   work schedule flexible
# 25038                                                                                                slow time
# 25039            bad management appropriate pay extremely long work hour extensive workload toxic work culture
# 25040                                                   work environment good need improve lot hr relate issue
#
#                                                            Cons Entities  \
# 0      {'NER': [('hours', 'TIME'), ('long hours', 'TIME')], 'ROLES': []}
# 1                                               {'NER': [], 'ROLES': []}
# 2                                      {'NER': [], 'ROLES': ['project']}
# 3                                               {'NER': [], 'ROLES': []}
# 4                                               {'NER': [], 'ROLES': []}
# ...                                                                  ...
# 25036                                           {'NER': [], 'ROLES': []}
# 25037                                           {'NER': [], 'ROLES': []}
# 25038                                           {'NER': [], 'ROLES': []}
# 25039              {'NER': [('hours', 'TIME')], 'ROLES': ['management']}
# 25040                               {'NER': [], 'ROLES': ['good', 'hr']}
#
#                            Cleaned Status  Cleaned Rating        Time  \
# 0       Former Employee, More Than 1 Year             5.0  2025-08-08
# 1                                Contract             4.0  2025-07-28
# 2      Former Employee, More Than 3 Years             4.0  2025-07-15
# 3                         Former Employee             5.0  2025-07-18
# 4                              Internship             5.0  2025-07-15
# ...                                   ...             ...         ...
# 25036                     Former Employee             4.0  2022-03-31
# 25037                    Current Employee             4.0  2022-05-14
# 25038                     Former Employee             3.0  2016-05-02
# 25039   Former Employee, More Than 1 Year             1.0  2022-10-17
# 25040  Former Employee, More Than 5 Years             1.0  2013-10-09
#
#       Employment_Type   Role_Type    Duration Company_Name  \
# 0              Former    employee  1 - 3 year    Safaricom
# 1             Current  contractor  1 - 3 year    Safaricom
# 2              Former    employee     >3 year    Safaricom
# 3              Former    employee     default    Safaricom
# 4              Former  internship     <1 year    Safaricom
# ...               ...         ...         ...          ...
# 25036          Former    employee     default       Equity
# 25037         Current    employee     default       Equity
# 25038          Former    employee     default       Equity
# 25039          Former    employee  1 - 3 year       Equity
# 25040          Former    employee     default       Equity
#
#                                                                                                                                                                                                                                       combined_text
# 0                             brand ambassador flexible hour supportive team good training fun work environment opportunity travel inconsistent hour limited career growth commission structure unclear stand long hour slow communication employee
# 1                                                                                                                                    senior mobile developer great gain experience large scale enterprise application lot shift priority contractor
# 2      project manager strong support professional growth training exposure largescale impactful project kenya competitive salary performancebased bonus occasional tight deadline highpressure timeline bureaucracy delay project signoff employee
# 3                                                                                                                                                                               ict technician working experience good major drawback talk employee
# 4                                                                                                                                                                                      intern great work environment regular bonus think internship
# ...                                                                                                                                                                                                                                             ...
# 25036                                                                                                                                                                planning officer good medical cover employee term employment contract employee
# 25037                                                                                                                                                         senior business analyst good learning potential staff work schedule flexible employee
# 25038                                                                                                                                                                       senior program manager potential great social impact slow time employee
# 25039                                                                  ban assurance officer medical insurance cover low interest loan staff bad management appropriate pay extremely long work hour extensive workload toxic work culture employee
# 25040                                                                                                               channel administrative exposure experience good growth possible work environment good need improve lot hr relate issue employee
#
# [25041 rows x 14 columns]

# %%
# load the transformer model
model = SentenceTransformer('all-MiniLM-L12-v2')

# %%
# generating job Embeddings
job_embeddings = model.encode(data2_cleaned['combined_text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/783 [00:00<?, ?it/s]

# %%
# save Embeddings for later use
np.save("job_embeddings.npy", job_embeddings)

# %%
# load embedding
job_embeddings = np.load("job_embeddings.npy")

# %%
# handle user query
user_query = "I want a remote internship that pays well"

# %%
# convert to embedding
user_embedding = model.encode([user_query])

# %%
# compute similarity score
similarity_scores = cosine_similarity(user_embedding, job_embeddings)[0]
similarity_scores
# Out:
# array([0.32478243, 0.328838  , 0.22624011, ..., 0.20577152, 0.2428226 ,
#        0.22375105], dtype=float32)

# %%
# rank and display top matches
data2_cleaned['similarity'] = similarity_scores
top_matches = data2_cleaned.sort_values(by='similarity', ascending=False).head(10)
top_matches[['Company_Name', 'Job Title Clean', 'similarity', 'Cleaned Rating', 'Role_Type']]
# Out:
#       Company_Name                         Job Title Clean  similarity  \
# 406      Safaricom                 remote support engineer    0.669340
# 3564        Google          software engineering intern ii    0.604513
# 92       Safaricom                       technology intern    0.602400
# 19292          IBM  specialist infrastructure architecture    0.589775
# 831         Google                         research intern    0.579647
# 22205        Cisco                  digital channel intern    0.575103
# 15663          IBM                 cloud consulting intern    0.572754
# 10707          IBM               software developer intern    0.569988
# 24412        Cisco      senior principal software engineer    0.567336
# 13386          IBM                         security intern    0.564940
#
#        Cleaned Rating   Role_Type
# 406               5.0  internship
# 3564              5.0    employee
# 92                4.0  contractor
# 19292             5.0    employee
# 831               5.0    employee
# 22205             5.0    employee
# 15663             4.0    employee
# 10707             3.0    employee
# 24412             4.0    employee
# 13386             4.0    employee

# %%
data2_cleaned.head(1)
# Out:
#     Job Title Clean  \
# 0  brand ambassador
#
#                                                   Job Title Entities  \
# 0  {'NER': [], 'ROLES': ['brand', 'brand ambassador', 'ambassador']}
#
#                                                                             Pros Clean  \
# 0  flexible hour supportive team good training fun work environment opportunity travel
#
#                                 Pros Entities  \
# 0  {'NER': [], 'ROLES': ['good', 'training']}
#
#                                                                                                 Cons Clean  \
# 0  inconsistent hour limited career growth commission structure unclear stand long hour slow communication
#
#                                                        Cons Entities  \
# 0  {'NER': [('hours', 'TIME'), ('long hours', 'TIME')], 'ROLES': []}
#
#                       Cleaned Status  Cleaned Rating        Time  \
# 0  Former Employee, More Than 1 Year             5.0  2025-08-08
#
#   Employment_Type Role_Type    Duration Company_Name  \
# 0          Former  employee  1 - 3 year    Safaricom
#
#                                                                                                                                                                                                            combined_text  \
# 0  brand ambassador flexible hour supportive team good training fun work environment opportunity travel inconsistent hour limited career growth commission structure unclear stand long hour slow communication employee
#
#    similarity
# 0    0.324782

# %%
# top_matches
# !pip install matplotlib seaborn scikit-learn wordcloud umap-learn

# %%
# visualization of the model using t-sne clusters
tsne = TSNE(n_components=2, random_state=42, perplexity=30, learning_rate=200)
job_embeddings_2d = tsne.fit_transform(job_embeddings)
data2_cleaned['x'] = job_embeddings_2d[:, 0]
data2_cleaned['y'] = job_embeddings_2d[:, 1]

#plot
plt.figure(figsize=(18, 7))
plt.style.use('seaborn-v0_8-darkgrid')
plt.scatter(data2_cleaned['x'], data2_cleaned['y'], c=data2_cleaned['Cleaned Rating'], cmap='viridis', s=50, alpha=.7)
plt.colorbar(label="Job Ratings")
plt.title('Job Embedding Clusters (t-SNE)')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# visualization using UMAP
import umap
reducer = umap.UMAP(n_neighbors=15, min_dist=.1, random_state=42)
job_embedding_umap = reducer.fit_transform(job_embeddings)

plt.figure(figsize=(18, 7))
plt.scatter(job_embedding_umap[:, 0],job_embedding_umap[:, 1],
           c=data2_cleaned['Cleaned Rating'], cmap='plasma', s=50, alpha=.7)
plt.colorbar(label="Job Ratings")
plt.title('Job Embedding Clusters (UMAP)')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
# word clouds for pros and cons of top matches
from wordcloud import WordCloud
pros_text = ' '.join(top_matches['Pros Clean'].dropna())
cons_text = ' '.join(top_matches['Cons Clean'].dropna())

# pros
plt.figure(figsize=(18, 7))
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(pros_text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Top Pros Mentioned")
plt.show()

# cons
plt.figure(figsize=(18, 7))
wordcloud = WordCloud(width=800, height=400, background_color="red").generate(pros_text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Cons Pros Mentioned")
plt.show()

# %%
# Pick top 10 similar jobs and compare their text similarity
similar_jobs = top_matches['combined_text'].head(10).tolist()
sim_matrix = cosine_similarity(model.encode(similar_jobs))

plt.figure(figsize=(18,7))
sns.heatmap(sim_matrix, cmap='coolwarm', annot=True)
plt.title('Job Similarity Heatmap')
plt.show()

# %%
# Normalize Job Ratings
scaler = MinMaxScaler()
data2_cleaned['Cleaned Rating'] = data2_cleaned['Cleaned Rating'].fillna(data2_cleaned['Cleaned Rating'].mean())
data2_cleaned['Rating_scaled'] = scaler.fit_transform(data2_cleaned[['Cleaned Rating']])

# %% [markdown]
# # structured Feature Engineering

# %%
# Encode
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
status_encoded = encoder.fit_transform(data2_cleaned[['Role_Type']])

status_cols = encoder.get_feature_names_out(['Role_Type'])
status_df = pd.DataFrame(status_encoded, columns=status_cols)

data2_cleaned = pd.concat([data2_cleaned.reset_index(drop=True), status_df.reset_index(drop=True)], axis=1)

# %%
# Combine Structured + Text Embeddings
# structured_features = np.concatenate(
#     [data2_cleaned[['Rating_scaled']].values, status_df.values],
#     axis=1
# )
structured_features = status_df.values  # Only categorical or numeric job info
hybrid_features = np.concatenate([job_embeddings, structured_features], axis=1)

# %%
# save for later
np.save("hybrid_features.npy", hybrid_features)

# %%
hybrid_features
# Out:
# array([[ 0.00984046,  0.08766761,  0.02423352, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.06434164,  0.05886243, -0.01085036, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.01632242,  0.0939292 , -0.03862968, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.0267743 ,  0.03906356, -0.00270649, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.01896854,  0.04508679, -0.03752998, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.02646735,  0.03551805, -0.02859724, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
data2_cleaned.columns
# Out:
# Index(['Job Title Clean', 'Job Title Entities', 'Pros Clean', 'Pros Entities',
#        'Cons Clean', 'Cons Entities', 'Cleaned Status', 'Cleaned Rating',
#        'Time', 'Employment_Type', 'Role_Type', 'Duration', 'Company_Name',
#        'combined_text', 'similarity', 'x', 'y', 'Rating_scaled',
#        'Role_Type_contractor', 'Role_Type_employee', 'Role_Type_freelancer',
#        'Role_Type_internship', 'Role_Type_temporary'],
#       dtype='object')

# %%
# normalize hybrid features
hybrid_features_norm = normalize(hybrid_features)

# %%
# user structured preferences
user_df = pd.DataFrame({'Role_Type': ['Internship']})

# transform using same encoder and scaler pipeline
user_status_pref = encoder.transform(user_df[['Role_Type']])
user_structured = user_status_pref

# combine embeddings
user_embedding = model.encode([user_query])
user_hybrid = np.concatenate([user_embedding, user_structured], axis=1)
user_hybrid_norm = normalize(user_hybrid)

# %%
# compute similarities
from sklearn.metrics.pairwise import cosine_similarity
similarity_scores = cosine_similarity(user_hybrid_norm, hybrid_features_norm)[0]
data2_cleaned["hybrid_similarity"] = similarity_scores
top_matches = data2_cleaned.sort_values(by="hybrid_similarity", ascending=False).head(10)
top_matches[['Company_Name', 'Job Title Clean', 'hybrid_similarity', 'Cleaned Rating', 'Role_Type']]
# Out:
#       Company_Name                         Job Title Clean  hybrid_similarity  \
# 406      Safaricom                 remote support engineer           0.473295
# 3564        Google          software engineering intern ii           0.427455
# 92       Safaricom                       technology intern           0.425961
# 19292          IBM  specialist infrastructure architecture           0.417034
# 831         Google                         research intern           0.409872
# 22205        Cisco                  digital channel intern           0.406659
# 15663          IBM                 cloud consulting intern           0.404998
# 10707          IBM               software developer intern           0.403042
# 24412        Cisco      senior principal software engineer           0.401167
# 13386          IBM                         security intern           0.399473
#
#        Cleaned Rating   Role_Type
# 406               5.0  internship
# 3564              5.0    employee
# 92                4.0  contractor
# 19292             5.0    employee
# 831               5.0    employee
# 22205             5.0    employee
# 15663             4.0    employee
# 10707             3.0    employee
# 24412             4.0    employee
# 13386             4.0    employee

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(hybrid_features, data2_cleaned['Cleaned Rating'], test_size=.2, random_state=42)
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)

preds = model_rf.predict(X_test)
mse = mean_squared_error(y_test, preds)
print(f"MSE: {mse}")
# Out:
# MSE: 0.9739766819724496

# %%
# # cluster profiling
# cluster_summary = data2_cleaned.groupby('cluster')[['Cleaned Rating']].mean()
# cluster_summary

# %%
# visualize 
importances = model_rf.feature_importances_
feature_labels = [f'Feature_{i}' for i in range(hybrid_features.shape[1])]

indices = importances.argsort()[-10:][::-1]
top_features = pd.DataFrame({
    "Feature": [feature_labels[i] for i in indices],
    "Importance": importances[indices]
})
# Plot heatmap
plt.figure(figsize=(18, 7))
sns.heatmap(top_features.set_index("Feature").T, annot=True, cmap="coolwarm", fmt=".3f")
plt.title("Top 10 Feature Importances (Random Forest)")
plt.show()

# %%
# Define a cleaning function
def preprocess_query_spacy(text):
    """
    A function that converts a text that says:
    i'm looking for an internship that lets me work from home and pays well
    into
    look internship let work home pay well"""
    doc = nlp(text.lower())
    tokens = [
        token.lemma_ for token in doc
        if not token.is_stop and not token.is_punct and not token.is_space
    ]
    return " ".join(tokens)

# %%
# embed the cleaned query
user_input = "i want a remote internship that pays well and offers experience"
cleaned_query = preprocess_query_spacy(user_input)
user_embedding = model.encode([cleaned_query], normalize_embeddings=True)

# %%
user_hybrid = np.concatenate([user_embedding, user_structured], axis=1)

# %%
similarity_scores = cosine_similarity(user_hybrid_norm, hybrid_features_norm)[0]
data2_cleaned["hybrid_similarity"] = similarity_scores
top_matches = data2_cleaned.sort_values(by="hybrid_similarity", ascending=False).head(10)
top_matches[['Company_Name', 'Job Title Clean', 'hybrid_similarity', 'Cleaned Rating', 'Role_Type']]
# Out:
#       Company_Name                         Job Title Clean  hybrid_similarity  \
# 406      Safaricom                 remote support engineer           0.473295
# 3564        Google          software engineering intern ii           0.427455
# 92       Safaricom                       technology intern           0.425961
# 19292          IBM  specialist infrastructure architecture           0.417034
# 831         Google                         research intern           0.409872
# 22205        Cisco                  digital channel intern           0.406659
# 15663          IBM                 cloud consulting intern           0.404998
# 10707          IBM               software developer intern           0.403042
# 24412        Cisco      senior principal software engineer           0.401167
# 13386          IBM                         security intern           0.399473
#
#        Cleaned Rating   Role_Type
# 406               5.0  internship
# 3564              5.0    employee
# 92                4.0  contractor
# 19292             5.0    employee
# 831               5.0    employee
# 22205             5.0    employee
# 15663             4.0    employee
# 10707             3.0    employee
# 24412             4.0    employee
# 13386             4.0    employee

# %%
def generate_relevance_labels(df, query):
    """
    create rule-based relevance labels for each company based on user query keywords
    Returns a dataframe with a new 'relevant column' """
    query = query.lower()

    wants_remote = "remote" in query
    wants_internship = "intern" in query
    wants_pay = any(word in query for word in ["pay", "salary", "money", "compensation"])
    wants_flex = "flex" in query

    df["relevance_score"] = 0

    if wants_remote:
        df.loc[df["Pros Clean"].str.contains("remote|home|hybrid", case=False, na=False), "relevance_score"] +=1

    if wants_internship:
        df.loc[df["Role_Type"].str.contains("intern", case=False, na=False), "relevance_score"] +=1

    if wants_pay:
        df.loc[df["Pros Clean"].str.contains("pay|salary|compensation|benefits", case=False, na=False), "relevance_score"] +=1
        df.loc[df["Cleaned Rating"]>=4, "relevance_score"] += .5

    if wants_flex:
        df.loc[df["Pros Clean"].str.contains("flexible|hours|schedule|part", case=False, na=False), "relevance_score"] +=1

    df["relevant"] = np.where(df["relevance_score"]>= 1.5, 1, 0)

    return df
    
data2_cleaned = generate_relevance_labels(data2_cleaned, user_query)

# %%
# evaluation function
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import ndcg_score

def evaluate_recommendation(df, k_values=[5, 10, 20]):
    """Evaluating recommendation performance using precision, recall, NDCG"""
    result = {}

    df_sorted = df.sort_values("similarity", ascending=False)

    y_true = df_sorted["relevant"].values
    y_score = df_sorted["similarity"].values

    for k in k_values:
        top_k_true = y_true[:k]
        top_k_pred = np.ones_like(top_k_true)

        precision = precision_score(top_k_true, top_k_pred, zero_division=0)
        recall = recall_score(y_true, np.concatenate([top_k_pred, np.zeros(len(y_true)-k)]), zero_division=0)

        ndcg = ndcg_score(y_true.reshape(1, -1), y_score.reshape(1, -1), k=k)

        result[k] = {
           "Precision": round(precision, 3),
            "Recall": round(recall, 3),
            "NDCG": round(ndcg, 3) 
        }
    return result

# %%
def evaluate_query(df, user_query):
    """Full evaluation pipeline for a given user query"""
    df_labeled = generate_relevance_labels(df.copy(), user_query)
    metrics = evaluate_recommendation(df_labeled)

    print(f"Query: '{user_query}'")
    for k, vals in metrics.items():
        print(f"\n@K={k}")
        print(f"  Precision: {vals['Precision']}")
        print(f"  Recall:    {vals['Recall']}")
        print(f"  NDCG:      {vals['NDCG']}")

    display(df_labeled[["Company_Name", "Role_Type", "Cleaned Rating", "relevance_score", "relevant", "similarity"]].head(10))

# %%
df_transform = data2_cleaned.copy()

# %%
df_transform["adjusted_score"] = df_transform["similarity"] / df_transform.groupby("Company_Name")["similarity"].transform("max")
df_transform = df_transform.sort_values("adjusted_score", ascending=False)

# %%
evaluate_query(df_transform, "remote internship pay more")
# Out:
# Query: 'remote internship pay more'
#
# @K=5
#   Precision: 0.8
#   Recall:    0.001
#   NDCG:      0.869
#
# @K=10
#   Precision: 0.6
#   Recall:    0.002
#   NDCG:      0.706
#
# @K=20
#   Precision: 0.55
#   Recall:    0.003
#   NDCG:      0.629
#        Company_Name   Role_Type  Cleaned Rating  relevance_score  relevant  \
# 24561          Bolt    employee             4.0              0.5         0
# 22205         Cisco    employee             5.0              1.5         1
# 3564         Google    employee             5.0              1.5         1
# 25011        Equity    employee             4.0              0.5         0
# 7473      MicroSoft    employee             5.0              0.5         0
# 406       Safaricom  internship             5.0              1.5         1
# 19292           IBM    employee             5.0              2.5         1
# 24703  Co-Operative    employee             2.0              0.0         0
# 24412         Cisco    employee             4.0              0.5         0
# 9368      MicroSoft    employee             5.0              0.5         0
#
#        similarity
# 24561    0.403950
# 22205    0.575103
# 3564     0.604513
# 25011    0.505305
# 7473     0.554977
# 406      0.669340
# 19292    0.589775
# 24703    0.507696
# 24412    0.567336
# 9368     0.543332

# %%
# saving the model for future usage
import pickle
with open("Best_model.pkl", 'wb') as file:
    pickle.dump(df_transform, file)

# %%
# Group and summarize
top_companies = (
    df_transform.groupby("Company_Name")
    .agg({
        "Cleaned Rating": "mean",
        "Employment_Type": lambda x: x.mode().iloc[0] if not x.mode().empty else "N/A",
        "Role_Type": lambda x: x.mode().iloc[0] if not x.mode().empty else "N/A",
        "Duration": "first",
        "Job Title Clean": lambda x: ', '.join(x.head(2)),  # show top 2 example roles
        "Pros Clean": lambda x: x.iloc[0][:120] + "..." if isinstance(x.iloc[0], str) else "",
        "Cons Clean": lambda x: x.iloc[0][:120] + "..." if isinstance(x.iloc[0], str) else ""
    })
    .reset_index()
    .sort_values(by="Cleaned Rating", ascending=False)
    .head(10)
)

# Round off numeric values
top_companies["Cleaned Rating"] = top_companies["Cleaned Rating"].round(2)
top_companies.set_index("Company_Name")
# Out:
#               Cleaned Rating Employment_Type Role_Type    Duration  \
# Company_Name
# Google                  4.31         Current  employee     <1 year
# Safaricom               4.16         Current  employee     <1 year
# MicroSoft               4.11         Current  employee     <1 year
# Cisco                   4.07         Current  employee  1 - 3 year
# IBM                     3.77         Current  employee     <1 year
# Bolt                    3.76         Current  employee  1 - 3 year
# Co-Operative            3.58         Current  employee     >3 year
# Equity                  3.44          Former  employee     <1 year
#
#                                                               Job Title Clean  \
# Company_Name
# Google                        software engineering intern ii, research intern
# Safaricom                          remote support engineer, technology intern
# MicroSoft                                doctoral intern, software internship
# Cisco              digital channel intern, senior principal software engineer
# IBM           specialist infrastructure architecture, cloud consulting intern
# Bolt                              senior software engineer, revenue operation
# Co-Operative                                       software developer, intern
# Equity                      market research intern, senior software developer
#
#                                                                                                                                Pros Clean  \
# Company_Name
# Google        largely relate remote working experience summer intern entirely remote work clear focus maintain highlevel communication...
# Safaricom                                                                                        good environment training workmanship...
# MicroSoft     researcher work like academia selfdirected smart able offer insightful facility lovely generous vacation time benefit ad...
# Cisco                                                                                         hybrid benefit great climate culture etc...
# IBM                                                                           remote work salary avaliation technology big opportunity...
# Bolt                                                                                                       decent place great coworker...
# Co-Operative                                                                                           good employee loan good medical...
# Equity                                                                                       good relationship employee like community...
#
#                                                                                            Cons Clean
# Company_Name
# Google                                                             free food coffee remote working...
# Safaricom                                                            long sit hour relaxation hour...
# MicroSoft     con work msr work doctoral intern disappoint opportunity hire fulltime finish degree...
# Cisco                                                                           friend remote work...
# IBM                                                                        maybe country benefitie...
# Bolt                                                                               leadership need...
# Co-Operative                                                           flexible hour option remote...
# Equity                                                                             love experience...

# %%
df_transform.set_index("Job Title Clean", inplace=True)

# %%
df_transform.reset_index(inplace=True)

# %%
# saving the file as csv
df_transform.to_csv("Company_Model.csv", index=False, sep='\t')

# %%
df_transform.shape
# Out:
# (25041, 27)
